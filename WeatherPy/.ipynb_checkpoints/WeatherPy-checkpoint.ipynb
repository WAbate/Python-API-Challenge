# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
import json
from scipy.stats import linregress

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#import API keys
api_key = "6329cb8812aeb843a21db371bd8d3187"

# Range of latitudes and longitudes
latitude_range = (-90, 90)
longitude_range = (-180, 180)

# %%
# List for holding latitude, longitude and cities
latitude_longitude = []
cities = []

# Create a set of random latitude and longitude combinations
Latitude = np.random.uniform(low=-90.000, high=90.000, size=2000)
Longitude = np.random.uniform(low=-180.000, high=180.000, size=2000)
latitude_longitude = zip(Latitude, Longitude)

# Identify nearest city for each latitude and longitude combinations
for lat_lng in latitude_longitude:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count 
len(cities)
# Out:
# 737

# %%
#Build URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" 
appid = wkey
settings = {"units": "imperial", "appid": wkey}
url = f"{url}appid={api_key}&units={units}"

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial'

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_latitute = city_weather["coord"]["lat"]
        city_longitude = city_weather["coord"]["lon"]
        city_max_temperature = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_latitute, 
                          "Lng": city_longitude, 
                          "Max Temp": city_max_temperature,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bluff
# Processing Record 2 of Set 1 | jati
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jati
# Processing Record 3 of Set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=poum
# Processing Record 4 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=busselton
# Processing Record 5 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bethel
# Processing Record 6 of Set 1 | calama
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=calama
# Processing Record 7 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=rikitea
# Processing Record 8 of Set 1 | maniwaki
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=maniwaki
# Processing Record 9 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ushuaia
# Processing Record 10 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=new%20norfolk
# Processing Record 11 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jamestown
# Processing Record 12 of Set 1 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=pacific%20grove
# Processing Record 13 of Set 1 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vao
# Processing Record 14 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nikolskoye
# Processing Record 15 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=cherskiy
# Processing Record 16 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=barrow
# Processing Record 17 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bredasdorp
# Processing Record 18 of Set 1 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vestmanna
# Processing Record 19 of Set 1 | birakan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=birakan
# Processing Record 20 of Set 1 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ambilobe
# Processing Record 21 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mataura
# Processing Record 22 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=pevek
# Processing Record 23 of Set 1 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=saint-joseph
# Processing Record 24 of Set 1 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sinnamary
# Processing Record 25 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=taolanaro
# City not found...
# Processing Record 26 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=carnarvon
# Processing Record 27 of Set 1 | plavsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=plavsk
# Processing Record 28 of Set 1 | alexandria
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=alexandria
# Processing Record 29 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=cidreira
# Processing Record 30 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vaitupu
# City not found...
# Processing Record 31 of Set 1 | chiclana
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=chiclana
# Processing Record 32 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=fortuna
# Processing Record 33 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=butaritari
# Processing Record 34 of Set 1 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=svetlogorsk
# Processing Record 35 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=thompson
# Processing Record 36 of Set 1 | murcia
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=murcia
# Processing Record 37 of Set 1 | inuvik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=inuvik
# Processing Record 38 of Set 1 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=fort%20nelson
# Processing Record 39 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=atuona
# Processing Record 40 of Set 1 | moussoro
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=moussoro
# Processing Record 41 of Set 1 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=port%20hedland
# Processing Record 42 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=cape%20town
# Processing Record 43 of Set 1 | dunmore town
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dunmore%20town
# Processing Record 44 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=barentsburg
# City not found...
# Processing Record 45 of Set 1 | lotoshino
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lotoshino
# Processing Record 46 of Set 1 | khasan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=khasan
# Processing Record 47 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=cabo%20san%20lucas
# Processing Record 48 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ribeira%20grande
# Processing Record 49 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tasiilaq
# Processing Record 50 of Set 1 | neijiang
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=neijiang
# Processing Record 0 of Set 2 | formosa do rio preto
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=formosa%20do%20rio%20preto
# Processing Record 1 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hithadhoo
# Processing Record 2 of Set 2 | vega de alatorre
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vega%20de%20alatorre
# Processing Record 3 of Set 2 | urucui
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=urucui
# Processing Record 4 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=punta%20arenas
# Processing Record 5 of Set 2 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=naze
# Processing Record 6 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hasaki
# Processing Record 7 of Set 2 | nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nantucket
# Processing Record 8 of Set 2 | sarangani
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sarangani
# Processing Record 9 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=torbay
# Processing Record 10 of Set 2 | jutai
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jutai
# Processing Record 11 of Set 2 | semey
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=semey
# Processing Record 12 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=upernavik
# Processing Record 13 of Set 2 | mahuva
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mahuva
# Processing Record 14 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=east%20london
# Processing Record 15 of Set 2 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=husavik
# Processing Record 16 of Set 2 | bontang
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bontang
# Processing Record 17 of Set 2 | guadix
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=guadix
# Processing Record 18 of Set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=saldanha
# Processing Record 19 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=norman%20wells
# Processing Record 20 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hermanus
# Processing Record 21 of Set 2 | rezekne
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=rezekne
# Processing Record 22 of Set 2 | lourdes
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lourdes
# Processing Record 23 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bengkulu
# Processing Record 24 of Set 2 | kaniama
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kaniama
# Processing Record 25 of Set 2 | bairiki
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bairiki
# Processing Record 26 of Set 2 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=rio%20gallegos
# Processing Record 27 of Set 2 | camacupa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=camacupa
# Processing Record 28 of Set 2 | mahudha
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mahudha
# Processing Record 29 of Set 2 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sur
# Processing Record 30 of Set 2 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=thunder%20bay
# Processing Record 31 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=port%20alfred
# Processing Record 32 of Set 2 | novoanninskiy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=novoanninskiy
# Processing Record 33 of Set 2 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lasa
# Processing Record 34 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=albany
# Processing Record 35 of Set 2 | la sarre
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=la%20sarre
# Processing Record 36 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hobart
# Processing Record 37 of Set 2 | palu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=palu
# Processing Record 38 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=illoqqortoormiut
# City not found...
# Processing Record 39 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=aklavik
# Processing Record 40 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dikson
# Processing Record 41 of Set 2 | barcelos
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=barcelos
# Processing Record 42 of Set 2 | loandjili
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=loandjili
# Processing Record 43 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=yellowknife
# Processing Record 44 of Set 2 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=rio%20grande
# Processing Record 45 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nanortalik
# Processing Record 46 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=chokurdakh
# Processing Record 47 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=talnakh
# Processing Record 48 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=guerrero%20negro
# Processing Record 49 of Set 2 | hit
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hit
# Processing Record 0 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=iqaluit
# Processing Record 1 of Set 3 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=half%20moon%20bay
# Processing Record 2 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mys%20shmidta
# City not found...
# Processing Record 3 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lorengau
# Processing Record 4 of Set 3 | madaoua
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=madaoua
# Processing Record 5 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=avarua
# Processing Record 6 of Set 3 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=severo-kurilsk
# Processing Record 7 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=esperance
# Processing Record 8 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mahebourg
# Processing Record 9 of Set 3 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=keti%20bandar
# Processing Record 10 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=laguna
# Processing Record 11 of Set 3 | noyabrsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=noyabrsk
# Processing Record 12 of Set 3 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=grand%20gaube
# Processing Record 13 of Set 3 | bafia
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bafia
# Processing Record 14 of Set 3 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nizhneyansk
# City not found...
# Processing Record 15 of Set 3 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vaini
# Processing Record 16 of Set 3 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kodinsk
# Processing Record 17 of Set 3 | jingdezhen
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jingdezhen
# Processing Record 18 of Set 3 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=la%20ronge
# Processing Record 19 of Set 3 | muroto
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=muroto
# Processing Record 20 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=georgetown
# Processing Record 21 of Set 3 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mnogovershinnyy
# Processing Record 22 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=khatanga
# Processing Record 23 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hilo
# Processing Record 24 of Set 3 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=atambua
# Processing Record 25 of Set 3 | peace river
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=peace%20river
# Processing Record 26 of Set 3 | gold coast
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gold%20coast
# Processing Record 27 of Set 3 | mopipi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mopipi
# Processing Record 28 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kodiak
# Processing Record 29 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=katsuura
# Processing Record 30 of Set 3 | malaga
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=malaga
# Processing Record 31 of Set 3 | guadalupe y calvo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=guadalupe%20y%20calvo
# Processing Record 32 of Set 3 | trat
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=trat
# Processing Record 33 of Set 3 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=avera
# Processing Record 34 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lompoc
# Processing Record 35 of Set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=saint-philippe
# Processing Record 36 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=port%20elizabeth
# Processing Record 37 of Set 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=puerto%20ayora
# Processing Record 38 of Set 3 | taree
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=taree
# Processing Record 39 of Set 3 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=buraydah
# Processing Record 40 of Set 3 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=palmer
# Processing Record 41 of Set 3 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=santa%20cruz
# Processing Record 42 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lebu
# Processing Record 43 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tuktoyaktuk
# Processing Record 44 of Set 3 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mogadishu
# Processing Record 45 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kavieng
# Processing Record 46 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=longyearbyen
# Processing Record 47 of Set 3 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=marsa%20matruh
# Processing Record 48 of Set 3 | goderich
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=goderich
# Processing Record 49 of Set 3 | kadykchan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kadykchan
# City not found...
# Processing Record 0 of Set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=luderitz
# Processing Record 1 of Set 4 | destin
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=destin
# Processing Record 2 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kruisfontein
# Processing Record 3 of Set 4 | makushino
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=makushino
# Processing Record 4 of Set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hofn
# Processing Record 5 of Set 4 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=yerbogachen
# Processing Record 6 of Set 4 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=fairbanks
# Processing Record 7 of Set 4 | lamar
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lamar
# Processing Record 8 of Set 4 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hobyo
# Processing Record 9 of Set 4 | panormos
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=panormos
# Processing Record 10 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ilulissat
# Processing Record 11 of Set 4 | vredendal
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vredendal
# Processing Record 12 of Set 4 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=coahuayana
# Processing Record 13 of Set 4 | kamina
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kamina
# Processing Record 14 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=arraial%20do%20cabo
# Processing Record 15 of Set 4 | podgornoye
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=podgornoye
# Processing Record 16 of Set 4 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=esmeraldas
# Processing Record 17 of Set 4 | west bay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=west%20bay
# Processing Record 18 of Set 4 | catalina foothills
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=catalina%20foothills
# Processing Record 19 of Set 4 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=saint%20george
# Processing Record 20 of Set 4 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vila%20franca%20do%20campo
# Processing Record 21 of Set 4 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tsihombe
# City not found...
# Processing Record 22 of Set 4 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=port%20macquarie
# Processing Record 23 of Set 4 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bud
# Processing Record 24 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=padang
# Processing Record 25 of Set 4 | foumban
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=foumban
# Processing Record 26 of Set 4 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=olafsvik
# Processing Record 27 of Set 4 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=broken%20hill
# Processing Record 28 of Set 4 | arroio grande
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=arroio%20grande
# Processing Record 29 of Set 4 | marcona
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=marcona
# City not found...
# Processing Record 30 of Set 4 | warqla
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=warqla
# City not found...
# Processing Record 31 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mar%20del%20plata
# Processing Record 32 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=qaanaaq
# Processing Record 33 of Set 4 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=yulara
# Processing Record 34 of Set 4 | asadabad
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=asadabad
# Processing Record 35 of Set 4 | methoni
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=methoni
# Processing Record 36 of Set 4 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=oktyabrskiy
# Processing Record 37 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=victoria
# Processing Record 38 of Set 4 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ugoofaaru
# Processing Record 39 of Set 4 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kalmunai
# Processing Record 40 of Set 4 | qurayyat
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=qurayyat
# Processing Record 41 of Set 4 | luganville
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=luganville
# Processing Record 42 of Set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=asau
# Processing Record 43 of Set 4 | xudat
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=xudat
# Processing Record 44 of Set 4 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kapaa
# Processing Record 45 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=port%20lincoln
# Processing Record 46 of Set 4 | klamath falls
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=klamath%20falls
# Processing Record 47 of Set 4 | bow island
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bow%20island
# Processing Record 48 of Set 4 | porto velho
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=porto%20velho
# Processing Record 49 of Set 4 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=okhotsk
# Processing Record 0 of Set 5 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jalu
# Processing Record 1 of Set 5 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=skalistyy
# City not found...
# Processing Record 2 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=faanui
# Processing Record 3 of Set 5 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=yenagoa
# Processing Record 4 of Set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=oranjemund
# Processing Record 5 of Set 5 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=narsaq
# Processing Record 6 of Set 5 | benguela
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=benguela
# Processing Record 7 of Set 5 | magadan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=magadan
# Processing Record 8 of Set 5 | marijampole
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=marijampole
# Processing Record 9 of Set 5 | dekar
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dekar
# Processing Record 10 of Set 5 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=belushya%20guba
# City not found...
# Processing Record 11 of Set 5 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tilichiki
# Processing Record 12 of Set 5 | oda
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=oda
# Processing Record 13 of Set 5 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=anadyr
# Processing Record 14 of Set 5 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=san%20luis
# Processing Record 15 of Set 5 | paradwip
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=paradwip
# City not found...
# Processing Record 16 of Set 5 | bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bonthe
# Processing Record 17 of Set 5 | seara
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=seara
# Processing Record 18 of Set 5 | beaufort
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=beaufort
# Processing Record 19 of Set 5 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=saskylakh
# Processing Record 20 of Set 5 | kallaste
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kallaste
# Processing Record 21 of Set 5 | ughelli
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ughelli
# Processing Record 22 of Set 5 | juifang
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=juifang
# City not found...
# Processing Record 23 of Set 5 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=buala
# Processing Record 24 of Set 5 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hamilton
# Processing Record 25 of Set 5 | nalut
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nalut
# Processing Record 26 of Set 5 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=henties%20bay
# Processing Record 27 of Set 5 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=arlit
# Processing Record 28 of Set 5 | stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=stykkisholmur
# Processing Record 29 of Set 5 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=clyde%20river
# Processing Record 30 of Set 5 | turbat
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=turbat
# Processing Record 31 of Set 5 | bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bodden%20town
# Processing Record 32 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=chuy
# Processing Record 33 of Set 5 | alenquer
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=alenquer
# Processing Record 34 of Set 5 | nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nishihara
# Processing Record 35 of Set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=portland
# Processing Record 36 of Set 5 | lucera
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lucera
# Processing Record 37 of Set 5 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=vardo
# Processing Record 38 of Set 5 | gurlan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gurlan
# Processing Record 39 of Set 5 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=rocha
# Processing Record 40 of Set 5 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=prince%20rupert
# Processing Record 41 of Set 5 | sorong
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sorong
# Processing Record 42 of Set 5 | gravdal
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gravdal
# Processing Record 43 of Set 5 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=cockburn%20town
# Processing Record 44 of Set 5 | santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=santa%20vitoria%20do%20palmar
# Processing Record 45 of Set 5 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lagoa
# Processing Record 46 of Set 5 | mecca
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mecca
# Processing Record 47 of Set 5 | brigantine
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=brigantine
# Processing Record 48 of Set 5 | ust-kalmanka
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ust-kalmanka
# Processing Record 49 of Set 5 | darhan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=darhan
# Processing Record 0 of Set 6 | gonbad-e qabus
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gonbad-e%20qabus
# Processing Record 1 of Set 6 | sambava
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sambava
# Processing Record 2 of Set 6 | sivas
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sivas
# Processing Record 3 of Set 6 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=klaksvik
# Processing Record 4 of Set 6 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=airai
# Processing Record 5 of Set 6 | kaifeng
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kaifeng
# Processing Record 6 of Set 6 | ayan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ayan
# Processing Record 7 of Set 6 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=seoul
# Processing Record 8 of Set 6 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gazanjyk
# Processing Record 9 of Set 6 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=talcahuano
# Processing Record 10 of Set 6 | sainte-rose
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sainte-rose
# Processing Record 11 of Set 6 | rafaela
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=rafaela
# Processing Record 12 of Set 6 | casablanca
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=casablanca
# Processing Record 13 of Set 6 | dasoguz
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dasoguz
# Processing Record 14 of Set 6 | tucuman
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tucuman
# Processing Record 15 of Set 6 | okoneshnikovo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=okoneshnikovo
# Processing Record 16 of Set 6 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ixtapa
# Processing Record 17 of Set 6 | byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=byron%20bay
# Processing Record 18 of Set 6 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kaitangata
# Processing Record 19 of Set 6 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mackenzie
# Processing Record 20 of Set 6 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=meulaboh
# Processing Record 21 of Set 6 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=castro
# Processing Record 22 of Set 6 | catuday
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=catuday
# Processing Record 23 of Set 6 | gizo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gizo
# Processing Record 24 of Set 6 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=waipawa
# Processing Record 25 of Set 6 | jasper
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jasper
# Processing Record 26 of Set 6 | dodge city
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dodge%20city
# Processing Record 27 of Set 6 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=thinadhoo
# Processing Record 28 of Set 6 | mulchen
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mulchen
# Processing Record 29 of Set 6 | san fernando
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=san%20fernando
# Processing Record 30 of Set 6 | claveria
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=claveria
# Processing Record 31 of Set 6 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=san%20policarpo
# Processing Record 32 of Set 6 | punta cardon
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=punta%20cardon
# Processing Record 33 of Set 6 | oakland
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=oakland
# Processing Record 34 of Set 6 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=salalah
# Processing Record 35 of Set 6 | sindand
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sindand
# City not found...
# Processing Record 36 of Set 6 | florianopolis
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=florianopolis
# Processing Record 37 of Set 6 | hvide sande
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hvide%20sande
# Processing Record 38 of Set 6 | sukhoy log
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sukhoy%20log
# Processing Record 39 of Set 6 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tiksi
# Processing Record 40 of Set 6 | trairi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=trairi
# Processing Record 41 of Set 6 | liepaja
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=liepaja
# Processing Record 42 of Set 6 | kafue
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kafue
# Processing Record 43 of Set 6 | manzhouli
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=manzhouli
# Processing Record 44 of Set 6 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=port%20blair
# Processing Record 45 of Set 6 | olavarria
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=olavarria
# Processing Record 46 of Set 6 | biltine
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=biltine
# Processing Record 47 of Set 6 | moundou
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=moundou
# Processing Record 48 of Set 6 | lubango
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lubango
# Processing Record 49 of Set 6 | riyadh
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=riyadh
# Processing Record 0 of Set 7 | chiredzi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=chiredzi
# Processing Record 1 of Set 7 | imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=imbituba
# Processing Record 2 of Set 7 | troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=troitsko-pechorsk
# Processing Record 3 of Set 7 | les cayes
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=les%20cayes
# Processing Record 4 of Set 7 | ternate
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ternate
# Processing Record 5 of Set 7 | balkhash
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=balkhash
# Processing Record 6 of Set 7 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=komsomolskiy
# Processing Record 7 of Set 7 | xinyu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=xinyu
# Processing Record 8 of Set 7 | ipixuna
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ipixuna
# Processing Record 9 of Set 7 | dingle
# ...
# Processing Record 36 of Set 13 | nauta
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nauta
# Processing Record 37 of Set 13 | richard toll
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=richard%20toll
# City not found...
# Processing Record 38 of Set 13 | nguiu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nguiu
# City not found...
# Processing Record 39 of Set 13 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=pontes%20e%20lacerda
# Processing Record 40 of Set 13 | celestun
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=celestun
# Processing Record 41 of Set 13 | batsfjord
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=batsfjord
# Processing Record 42 of Set 13 | asosa
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=asosa
# Processing Record 43 of Set 13 | bondoukou
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bondoukou
# Processing Record 44 of Set 13 | paralimni
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=paralimni
# Processing Record 45 of Set 13 | santa ines
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=santa%20ines
# Processing Record 46 of Set 13 | tongzi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tongzi
# Processing Record 47 of Set 13 | baculin
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=baculin
# Processing Record 48 of Set 13 | ingham
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ingham
# Processing Record 49 of Set 13 | puerto pailas
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=puerto%20pailas
# Processing Record 0 of Set 14 | mbanza-ngungu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mbanza-ngungu
# Processing Record 1 of Set 14 | jiddah
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=jiddah
# City not found...
# Processing Record 2 of Set 14 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=berlevag
# Processing Record 3 of Set 14 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=flinders
# Processing Record 4 of Set 14 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ketchikan
# Processing Record 5 of Set 14 | tabou
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tabou
# Processing Record 6 of Set 14 | bahia blanca
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bahia%20blanca
# Processing Record 7 of Set 14 | slawno
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=slawno
# Processing Record 8 of Set 14 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bereda
# Processing Record 9 of Set 14 | tamandare
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=tamandare
# Processing Record 10 of Set 14 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kurilsk
# Processing Record 11 of Set 14 | plouzane
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=plouzane
# Processing Record 12 of Set 14 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=omsukchan
# Processing Record 13 of Set 14 | silver city
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=silver%20city
# Processing Record 14 of Set 14 | mamontovo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mamontovo
# Processing Record 15 of Set 14 | batagay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=batagay
# Processing Record 16 of Set 14 | libreville
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=libreville
# Processing Record 17 of Set 14 | palmas de monte alto
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=palmas%20de%20monte%20alto
# Processing Record 18 of Set 14 | porto novo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=porto%20novo
# Processing Record 19 of Set 14 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=touros
# Processing Record 20 of Set 14 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ucluelet
# Processing Record 21 of Set 14 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=zyryanka
# Processing Record 22 of Set 14 | deep river
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=deep%20river
# Processing Record 23 of Set 14 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hervey%20bay
# Processing Record 24 of Set 14 | huainan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=huainan
# Processing Record 25 of Set 14 | siyana
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=siyana
# Processing Record 26 of Set 14 | mugumu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mugumu
# Processing Record 27 of Set 14 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ngukurr
# City not found...
# Processing Record 28 of Set 14 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sao%20jose%20da%20coroa%20grande
# Processing Record 29 of Set 14 | agua verde
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=agua%20verde
# Processing Record 30 of Set 14 | parnarama
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=parnarama
# Processing Record 31 of Set 14 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=kulhudhuffushi
# Processing Record 32 of Set 14 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=moose%20factory
# Processing Record 33 of Set 14 | sohbatpur
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sohbatpur
# Processing Record 34 of Set 14 | wyndham
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=wyndham
# Processing Record 35 of Set 14 | johnson city
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=johnson%20city
# Processing Record 36 of Set 14 | capuluan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=capuluan
# Processing Record 37 of Set 14 | mudanya
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mudanya
# Processing Record 38 of Set 14 | elizabethtown
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=elizabethtown
# Processing Record 39 of Set 14 | marzuq
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=marzuq
# Processing Record 40 of Set 14 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=arman
# Processing Record 41 of Set 14 | sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sao%20miguel%20do%20araguaia
# Processing Record 42 of Set 14 | monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=monrovia
# Processing Record 43 of Set 14 | megion
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=megion
# Processing Record 44 of Set 14 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=yarmouth
# Processing Record 45 of Set 14 | dawson creek
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dawson%20creek
# Processing Record 46 of Set 14 | chimoio
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=chimoio
# Processing Record 47 of Set 14 | puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=puerto%20leguizamo
# Processing Record 48 of Set 14 | karangampel
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=karangampel
# Processing Record 49 of Set 14 | chicama
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=chicama
# Processing Record 0 of Set 15 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=axim
# Processing Record 1 of Set 15 | nyandoma
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nyandoma
# Processing Record 2 of Set 15 | hunchun
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=hunchun
# Processing Record 3 of Set 15 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=abu%20dhabi
# Processing Record 4 of Set 15 | serowe
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=serowe
# Processing Record 5 of Set 15 | ushumun
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ushumun
# Processing Record 6 of Set 15 | sri aman
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sri%20aman
# Processing Record 7 of Set 15 | lebedinyy
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=lebedinyy
# Processing Record 8 of Set 15 | agua buena
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=agua%20buena
# Processing Record 9 of Set 15 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mitsamiouli
# Processing Record 10 of Set 15 | burlington
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=burlington
# Processing Record 11 of Set 15 | sinkat
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sinkat
# City not found...
# Processing Record 12 of Set 15 | ibotirama
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ibotirama
# Processing Record 13 of Set 15 | adre
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=adre
# Processing Record 14 of Set 15 | nan
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nan
# Processing Record 15 of Set 15 | huntsville
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=huntsville
# Processing Record 16 of Set 15 | bejar
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=bejar
# Processing Record 17 of Set 15 | gualeguaychu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=gualeguaychu
# Processing Record 18 of Set 15 | halalo
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=halalo
# City not found...
# Processing Record 19 of Set 15 | mandera
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=mandera
# Processing Record 20 of Set 15 | acajutla
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=acajutla
# Processing Record 21 of Set 15 | murchison
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=murchison
# Processing Record 22 of Set 15 | elko
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=elko
# Processing Record 23 of Set 15 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=nemuro
# Processing Record 24 of Set 15 | burica
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=burica
# City not found...
# Processing Record 25 of Set 15 | sinegorye
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=sinegorye
# Processing Record 26 of Set 15 | luorong
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=luorong
# Processing Record 27 of Set 15 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ahuimanu
# Processing Record 28 of Set 15 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=saint-augustin
# Processing Record 29 of Set 15 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=dunedin
# Processing Record 30 of Set 15 | acarau
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=acarau
# Processing Record 31 of Set 15 | poya
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=poya
# Processing Record 32 of Set 15 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=warrnambool
# Processing Record 33 of Set 15 | ovalle
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=ovalle
# Processing Record 34 of Set 15 | invermere
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=invermere
# Processing Record 35 of Set 15 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=aksu
# Processing Record 36 of Set 15 | simpang
# http://api.openweathermap.org/data/2.5/weather?appid=6329cb8812aeb843a21db371bd8d3187&units=imperial&q=simpang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Export the City_Data into a csv
city_data_pd.to_csv("WeatherPy.csv",encoding="utf-8",index=False)


# Show Record Count
city_data_pd.count()
# Out:
# City          687
# Lat           687
# Lng           687
# Max Temp      687
# Humidity      687
# Cloudiness    687
# Wind Speed    687
# Country       687
# Date          687
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      bluff -46.6000  168.3333     63.81        67          20        1.92
# 1       jati  24.3539   68.2671     81.34        78           2       14.67
# 2       poum -20.2333  164.0167     77.97        78           6        7.78
# 3  busselton -33.6500  115.3333     60.48        48           5       13.94
# 4     bethel  41.3712  -73.4140     52.65        85          94        5.01
#
#   Country        Date
# 0      NZ  1651629522
# 1      PK  1651629523
# 2      NC  1651629523
# 3      AU  1651629402
# 4      US  1651629524

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Max Temp"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
sns.set()

# Save the figure
plt.savefig("Latitude vs Temperature (F).png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
sns.set()

# Save the figure
plt.savefig("Latitude vs Humidity (%).png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
sns.set()

# Save the figure
plt.savefig("Latitude vs Cloudiness (%).png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(city_data_pd["Lat"], 
            city_data_pd["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
sns.set()

# Save the figure
plt.savefig("Latitude vs Wind Speed (MPH).png")

# Show plot
plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem = city_data_pd.loc[city_data_pd["Lat"] >=0]
south_hem = city_data_pd.loc[city_data_pd["Lat"] < 0]

# %%
def linear_reg(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    regress_values = x_values * slope + intercept
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values)
    
    plt.plot(x_values, regress_values,"r-")
    
    plt.annotate(line_eq,(x_values.median(),y_values.median()), fontsize=14, color="red")
    
    print(f"The r-value is: {rvalue}")
    
    return line_eq

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = north_hem["Lat"]

y_values = north_hem["Max Temp"]

plt.title("Max Temp vs. Latitude Linear Regression")

plt.ylabel("Max Temp (F)")

plt.xlabel("Latitude")

plt.show

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: -0.8907750842030341
# y = -0.89x + 92.46

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = south_hem["Lat"]

y_values = south_hem["Max Temp"]

plt.title("Max Temp vs. Latitude Linear Regression")

plt.ylabel("Max Temp (F)")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: 0.6482835553909312
# y = 0.55x + 80.53

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = north_hem["Lat"]

y_values = north_hem["Humidity"]

plt.title("Humidity vs. Latitude Linear Regression")

plt.ylabel("Humidity (%)")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: 0.12463000127101558
# y = 0.14x + 65.0

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = south_hem["Lat"]

y_values = south_hem["Humidity"]

plt.title("Humidity vs. Latitude Linear Regression")

plt.ylabel("Humidity (%)")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: 0.2672189436282313
# y = 0.34x + 81.03

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = north_hem["Lat"]

y_values = north_hem["Cloudiness"]

plt.title("Cloudiness vs. Latitude Linear Regression")

plt.ylabel("Cloudiness (%)")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: 0.1081002226760801
# y = 0.21x + 55.08

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = south_hem["Lat"]

y_values = south_hem["Cloudiness"]

plt.title("Cloudiness vs. Latitude Linear Regression")

plt.ylabel("Cloudiness (%)")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: 0.2961806906649051
# y = 0.89x + 66.73

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = north_hem["Lat"]

y_values = north_hem["Wind Speed"]

plt.title("Wind Speed (mph) vs. Latitude Linear Regression")

plt.ylabel("Wind Speed")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: 0.17887580882673076
# y = 0.05x + 6.22

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

x_values = south_hem["Lat"]

y_values = south_hem["Wind Speed"]

plt.title("Wind Speed (mph) vs. Latitude Linear Regression")

plt.ylabel("Wind Speed")

plt.xlabel("Latitude")

print(linear_reg(x_values, y_values))
# Out:
# The r-value is: -0.2578461740874484
# y = -0.1x + 5.16
